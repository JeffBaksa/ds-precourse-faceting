# %% [markdown]
# # Faceting
# ---

# %% [markdown]
# ## Challenges
#
# For the lessons on plotting in DSI precourse, instead of doing regular challenges - you're being asked to write the code to make some basic plots in this Jupyter Notebook before committing your work and submitting the URL to your repository.
#
# To do so, you must be sure to first fork and clone this repo, and if you aren't sure how to do that, you can look back to those instructions [here.](https://learn-2.galvanize.com/content_link/github/gSchool/dsi-prep-module-setup/units/04_github/03_fork_clone_pull.md)
#
# The completion of this module requires a basic understanding of numpy, pandas, and matplotlib.pyplot. Please **_do not_** use any of the pandas built-in visualization tools.
#
# Lastly, you'll need to execute the cells with existing code to import the modules, and the data.

# %% [markdown]
# ### Challenge 1
#
# For this challenge, you will be using the Johnson and Johnson Data set from before. You will need to do a little work to organize this data in a way that is useful for plotting.
#
# ```
#       Qtr1  Qtr2  Qtr3  Qtr4
#       ----  ----  ----  ----
# 1960  0.71  0.63  0.85  0.44
# 1961  0.61  0.69  0.92  0.55
# 1962  0.72  0.77  0.92  0.60
# 1963  0.83  0.80  1.00  0.77
# 1964  0.92  1.00  1.24  1.00
# 1965  1.16  1.30  1.45  1.25
# 1966  1.26  1.38  1.86  1.56
# 1967  1.53  1.59  1.83  1.86
# 1968  1.53  2.07  2.34  2.25
# 1969  2.16  2.43  2.70  2.25
# 1970  2.79  3.42  3.69  3.60
# 1971  3.60  4.32  4.32  4.05
# 1972  4.86  5.04  5.04  4.41
# 1973  5.58  5.85  6.57  5.31
# 1974  6.03  6.39  6.93  5.85
# 1975  6.93  7.74  7.83  6.12
# 1976  7.74  8.91  8.28  6.84
# 1977  9.54 10.26  9.54  8.73
# 1978 11.88 12.06 12.15  8.91
# 1979 14.04 12.96 14.85  9.99
# 1980 16.20 14.67 16.02 11.61
#
# ```
#
# * Create a 4 row and 1 column plot where:
#     * The first row is a line graph of all the first quater earnings
#     * The second row is a line graph of all the second quater earnings
#     * The third row is a line graph of all the third quater earnings
#     * The fourth row is a line graph of all the fourth quater earnings
# * All the plots should have a title saying what quarter is being shown
# * All the plots plots but the final should not have an x-axis, the final plot should only have the even years on the axis
# * The y-axis should be called "Earnings"
# * The x-axis should be called "Year"
# * The whole plot should be titled "Johnson and Johnson Quarterly Earnings"

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = np.array( [  0.71,  0.63,  0.85,  0.44,
                    0.61,  0.69,  0.92,  0.55,
                    0.72,  0.77,  0.92,  0.60,
                    0.83,  0.80,  1.00,  0.77,
                    0.92,  1.00,  1.24,  1.00,
                    1.16,  1.30,  1.45,  1.25,
                    1.26,  1.38,  1.86,  1.56,
                    1.53,  1.59,  1.83,  1.86,
                    1.53,  2.07,  2.34,  2.25,
                    2.16,  2.43,  2.70,  2.25,
                    2.79,  3.42,  3.69,  3.60,
                    3.60,  4.32,  4.32,  4.05,
                    4.86,  5.04,  5.04,  4.41,
                    5.58,  5.85,  6.57,  5.31,
                    6.03,  6.39,  6.93,  5.85,
                    6.93,  7.74,  7.83,  6.12,
                    7.74,  8.91,  8.28,  6.84,
                    9.54, 10.26,  9.54,  8.73,
                    11.88, 12.06, 12.15,  8.91,
                    14.04, 12.96, 14.85,  9.99,
                    16.20, 14.67, 16.02, 11.61  ])

years = np.array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980])

# Your code below (You need to make the appropriate imports of matplotlib and numpy)
qrtr1 = data[0::4]
qrtr2 = data[1::4]
qrtr3 = data[2::4]
qrtr4 = data[3::4]

# Create the figure
plt.figure()
plt.figtext(0.5, 0.99, 'Johnson and Johnson Quarterly Earnings', ha='center', fontsize=14)
plt.figtext(0.0001, 0.5, 'Earnings', va='center', rotation='vertical')

# Quarter 1
plt.subplot(4, 1, 1) # The figure has 4 rows, 1 columns, and this plot is the first plot
plt.title('Quarter 1')
#plt.xlabel('Year')
#plt.ylabel('Earnings')
plt.plot(years, qrtr1)
#plt.xticks(np.arange(min(years), max(years)+1, 2), rotation=45)
plt.xticks([])
plt.yticks(np.arange(0, max(data), 5))
#plt.show()

# Quarter 2
plt.subplot(4, 1, 2)
plt.title('Quarter 2')
#plt.xlabel('Year')
#plt.ylabel('Earnings')
plt.plot(years, qrtr2)
#plt.xticks(np.arange(min(years), max(years)+1, 2), rotation=45)
plt.xticks([])
plt.yticks(np.arange(0, max(data), 5))
#plt.show()

# Quarter 3
plt.subplot(4, 1, 3)
plt.title('Quarter 3')
#plt.xlabel('Year')
#plt.ylabel('Earnings')
plt.plot(years, qrtr3)
#plt.xticks(np.arange(min(years), max(years)+1, 2), rotation=45)
plt.xticks([])
plt.yticks(np.arange(0, max(data), 5))
#plt.show()

# Quarter 4
plt.subplot(4, 1, 4)
plt.title('Quarter 4')
plt.xlabel('Year')
#plt.ylabel('Earnings')
plt.plot(years, qrtr4)
plt.xticks(np.arange(min(years), max(years)+1, 2), rotation=45)
plt.yticks(np.arange(0, max(data), 5))

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Once you're happy with your plot, paste your code in the cell below. Replace `plt.show()` with `plt.savefig('../images/jj_qrtr_earnings.png')` and execute the cell to export the image to a file
#
# This is a technique that is not shown in the lesson, but is perhaps the most common way that you might create an image which you are able to share or implement in a presentation.

# %%
# Paste your code here and export it
# Create the figure
plt.figure()
plt.figtext(0.5, 0.99, 'Johnson and Johnson Quarterly Earnings', ha='center', fontsize=14)
plt.figtext(0.0001, 0.5, 'Earnings', va='center', rotation='vertical')

# Quarter 1
plt.subplot(4, 1, 1) # The figure has 4 rows, 1 columns, and this plot is the first plot
plt.title('Quarter 1')
plt.plot(years, qrtr1)
plt.xticks([])
plt.yticks(np.arange(0, max(data), 5))

# Quarter 2
plt.subplot(4, 1, 2)
plt.title('Quarter 2')
plt.plot(years, qrtr2)
plt.xticks([])
plt.yticks(np.arange(0, max(data), 5))

# Quarter 3
plt.subplot(4, 1, 3)
plt.title('Quarter 3')
plt.plot(years, qrtr3)
plt.xticks([])
plt.yticks(np.arange(0, max(data), 5))

# Quarter 4
plt.subplot(4, 1, 4)
plt.title('Quarter 4')
plt.xlabel('Year')
plt.plot(years, qrtr4)
plt.xticks(np.arange(min(years), max(years)+1, 2), rotation=45)
plt.yticks(np.arange(0, max(data), 5))

plt.tight_layout()
plt.savefig('../images/jj_qrtr_earnings.png')

# %% [markdown]
# ### Challenge 2
#
# For this challenge you will be working with the **cars** data set. Run the cell below to import the data set.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

cars_data = pd.read_csv('../data/cars.csv', sep='|')
cars_data.rename(columns={'Unnamed: 0': 'make_model'}, inplace=True)
cars_data.head()
# Out:
#           make_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# For this challenge:
# * Facet the plots on the number of cylenders each vehical has
# * Create a single row with with the number of correct plots
# * Use a scatter plot to show the relation between horse power and quarter mile time
# * On the x axis plot the horse power
# * On the y axis plot the the quarter mile time (qsec)
# * Each plot should have a title saying the number of cylinders
# * Give each axis an appropriate name

# %%
# Write your code here
four_cyl = cars_data.cyl == 4
six_cyl = cars_data.cyl == 6
eight_cyl = cars_data.cyl == 8

# Create the figure
plt.figure()
plt.figtext(0.5, 0.99, 'Quarter Mile Time vs Horse Power', ha='center', fontsize=14)
plt.figtext(0.0001, 0.5, 'Quarter Mile Time (Qsec)', va='center', rotation='vertical')

# Quarter 1
plt.subplot(3, 1, 1) # The figure has 3 rows, 1 columns, and this plot is the first plot
plt.title('4 Cylender Vehicles')
plt.scatter(cars_data.hp[four_cyl], cars_data.qsec[four_cyl])
plt.xticks([])
plt.yticks(np.arange(0, max(cars_data.qsec) + 5, 5))

# Quarter 2
plt.subplot(3, 1, 2)
plt.title('6 Cylender')
plt.scatter(cars_data.hp[six_cyl], cars_data.qsec[six_cyl])
plt.xticks([])
plt.yticks(np.arange(0, max(cars_data.qsec) + 5, 5))

# Quarter 3
plt.subplot(3, 1, 3)
plt.title('8 Cylender')
plt.xlabel('Horse Power')
plt.scatter(cars_data.hp[eight_cyl], cars_data.qsec[eight_cyl])
plt.xticks(np.arange(0, max(cars_data.hp)+1, 20), rotation=45)
plt.yticks(np.arange(0, max(cars_data.qsec) + 5, 5))

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Once you're happy with your plot, paste your code in the cell below. Replace `plt.show()` with `plt.savefig('../images/facet_cyl_cars.png')` and execute the cell to export the image to a file
#
# This is a technique that is not shown in the lesson, but is perhaps the most common way that you might create an image which you are able to share or implement in a presentation.

# %%
# export code here
# Create the figure
plt.figure()
plt.figtext(0.5, 0.99, 'Quarter Mile Time vs Horse Power', ha='center', fontsize=14)
plt.figtext(0.0001, 0.5, 'Quarter Mile Time (Qsec)', va='center', rotation='vertical')

# Quarter 1
plt.subplot(3, 1, 1) # The figure has 3 rows, 1 columns, and this plot is the first plot
plt.title('4 Cylender Vehicles')
plt.scatter(cars_data.hp[four_cyl], cars_data.qsec[four_cyl])
plt.xticks([])
plt.yticks(np.arange(0, max(cars_data.qsec) + 5, 5))

# Quarter 2
plt.subplot(3, 1, 2)
plt.title('6 Cylender')
plt.scatter(cars_data.hp[six_cyl], cars_data.qsec[six_cyl])
plt.xticks([])
plt.yticks(np.arange(0, max(cars_data.qsec) + 5, 5))

# Quarter 3
plt.subplot(3, 1, 3)
plt.title('8 Cylender')
plt.xlabel('Horse Power')
plt.scatter(cars_data.hp[eight_cyl], cars_data.qsec[eight_cyl])
plt.xticks(np.arange(0, max(cars_data.hp)+1, 20), rotation=45)
plt.yticks(np.arange(0, max(cars_data.qsec) + 5, 5))

plt.tight_layout()
plt.savefig('../images/facet_cyl_cars.png')
